# %% [markdown]
# # Russian Language Processing

# %%
pip install nltk

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading https://files.pythonhosted.org/packages/23/4e/1254d26ce5d36facdcbb5820e7e434328aed68e99938c75c9d4e2fee5efb/wordcloud-1.5.0-cp37-cp37m-win_amd64.whl (153kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\595872\appdata\local\continuum\anaconda3\lib\site-packages (from wordcloud) (1.16.2)
# Requirement already satisfied: pillow in c:\users\595872\appdata\local\continuum\anaconda3\lib\site-packages (from wordcloud) (5.4.1)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports for Russian language processing.

import csv
import pandas as pd
# Allows all dataframe columns to be displayed
pd.set_option('display.max_columns', 500)

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer
# >>> print(" ".join(SnowballStemmer.languages)) # See which languages are supported
# arabic danish dutch english finnish french german hungarian
# italian norwegian porter portuguese romanian russian
# spanish swedish

import nltk

nltk.download

from nltk.corpus import stopwords
from string import punctuation
import matplotlib.pyplot as plt
import numpy as np
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # nltk.tokenize.punkt

# %%
# nltk.tokenize.punkt module
# Punkt Sentence Tokenizer

# This tokenizer divides a text into a list of sentences by using an unsupervised algorithm to build a model for abbreviation 
# words, collocations, and words that start sentences. It must be trained on a large collection of plaintext in the target 
# language before it can be used.

# The NLTK data package includes a pre-trained Punkt tokenizer for English.

# %%
import nltk
nltk.download('punkt')
import nltk.data
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\595872\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenizes the Russian text stored in the "text" variable and then prints the origianl text as well as the tokenized results.

tokenizer = nltk.data.load('tokenizers/punkt/russian.pickle')
#text = 'Когда было много-много событий за последние два месяца, вот, буквально, каждый день по два - три мероприятия - конкурсы по разным дисциплинам, концерты - то инструменты, то хореография, экзамены в художественной школе, в новую школу по математике, дни рождения с родственниками и столами, участие в спектаклях... А мама что? Мама родительский комитет и всё это организовывыла, включая выпускной. В общем, итог прекрасный, два красных диплома ДШИ, три отделения закончили и новая школа на горизонте, но... как восстановиться? Мне сейчас даже дышать неимоверно трудно(( Есть какая-то быстрая помощь? Питание, физнагрузки или покой, что-то ещё? Пока только Ламбруско могу пить) Может фильм посмотреть? Ёлки, и это я ещё опытная, с многолетним стажем в РК))) И, надо же, так навернулась...))))))) Вот прям чувствую, что край - край(('
#text = re.sub('[?.,();:]', ' ', text)
#print(nltk.word_tokenize(text))

# %%
text1 = "???By now you will have a sense of the capabilities of the Python programming language for processing natural language. However, if you're new to Python or to programming, you may still be wrestling with Python and not feel like you are in full control yet. In this chapter we'll address the following questions, How can you write well-structured, readable programs that you and others will be able to re-use easily?  How do the fundamental building blocks work, such as loops, functions and assignment?  What are some of the pitfalls with Python programming and how can you avoid them?  Along the way, you will consolidate your knowledge of fundamental programming constructs, learn more about using features of the Python language in a natural and concise way, and learn some useful techniques in visualizing natural language data. As before, this chapter contains many examples and exercises (and as before, some exercises introduce new material). Readers new to programming should work through them carefully and consult other introductions to programming if necessary; experienced programmers can quickly skim this chapter.  In the other chapters of this book, we have organized the programming concepts as dictated by the needs of NLP. Here we revert to a more conventional approach where the material is more closely tied to the structure of the programming language. There's not room for a complete presentation of the language, so we'll just focus on the language constructs and idioms that are most important for NLP."
text1 = re.sub('[?.,();:]', ' ', text1)
# text1 = re.sub('\s+', ' ', text1)
# print(text1)
print(nltk.word_tokenize(text1))

# %%
# tokenizes the desired text and then converts the list or string to .Text.  This is required to use .concordance

tokens = nltk.word_tokenize(tweet)
tweet_words2 = nltk.Text(tokens)

# %%
# Allows a user to search for individual words within the text and returns every instance of the word along with the 
# phrase its found in.

search_term = input('What term would you like to search for? ')

tokens = nltk.word_tokenize(text)
tokenized_text = nltk.Text(tokens)
tokenized_text.concordance(search_term)
#tokenized_text.similar('много')

# %%
# Creates a variable that stores russian stopwords.

ru_stopwords = stopwords.words('russian')

# %%
ru_stopwords

# %%
rustopwords = ' '.join(ru_stopwords[:])

# %%
rustopwords

# %%
# Returns the root word of a word.

stemmer = SnowballStemmer("german") # Choose a language
stemmer.stem("Beir") # Stem a word

# %%
f=open('russian_sample.txt','rU')
raw=f.read()
tokens = nltk.word_tokenize(raw)
#tokens = nltk.word_tokenize(raw), lang='rus'
text_ru = nltk.Text(tokens)

# %%
text_ru

# %% [markdown]
# # Working with Pandas Dataframes

# %%
# read in dfs
#start = time.time()
#forumsdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\forums.csv').fillna('None')
#newsdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\news.csv').fillna('None')
#instagramdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\instagram.csv').fillna('None')
#tumblrdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\tumblr.csv').fillna('None')
#twitterdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\twitter.csv').fillna('None')
#end = time.time()
#print(end-start)

#start = time.time()
forumsdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\forums.csv')
newsdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\news.csv')
instagramdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\instagram.csv')
tumblrdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\tumblr.csv')
twitterdf = pd.read_csv(r'C:\Users\595872\Desktop\Data_Science\Examples\techday_nlp_demo\data\clean_dfs\twitter.csv')
#end = time.time()
#print(end-start)

# %%
# Title, Snippet, Contents, Summary,
print(forumsdf.head(0))
print(' ')

# Title, Snippet, Contents, Summary,
print(newsdf.head(0))
print(' ')


print(instagramdf.head(0))
print(' ')

# Title, Snippet, Contents, Summary,
print(tumblrdf.head(0))
print(' ')

# Title, Snippet, Contents, Summary,
print(twitterdf.head(0))

# %%
# Function to check for NaN and return the rows with NaN.  Currently it will only work for one series at a time.

def check_NaN(with_na):

    with_na[with_na['Summary'].isna().sum()
    #with_na = with_na[with_na['Contents'].isna()]
    #with_na = with_na[with_na['Snippet'].isna()]

    return with_na

# %%
def NaN_iteration(df):
    for data in df:
        print(df, 'NaN Results')
        print('')
        print('Title:', df['Title'].isna().sum())
        print('Snippet:', df['Snippet'].isna().sum())
        print('Contents:', df['Contents'].isna().sum())
        print('Summary:', df['Summary'].isna().sum())

# %%
def remove_NaN(df):
    
    df = df.fillna('None')
    
    return df

# %%
forumsdf[forumsdf['Summary'].isna()]

# %%
check_NaN(forumsdf)
#twitterdf_dropna = replace_NaN(twitterdf)

# %%
forumsdf_withna
#twitterdf_dropna

# %%
twitterdf.index

# %%
#twitterdf.info()
len(twitterdf)

# %%
#twitterdf[twitterdf['Contents'].isnull()]
#df[df['A'].isnull()].index.tolist()
twitterdf[twitterdf['Contents'].isna()]

# %%
#twitterdf.head()

# %%
twitter_contents = twitterdf.Contents

# %%
twitter_contents[4]

# %%
twitterdf.shape

# %%
tokens_text

# %%
#for word in tokenized_text:
    #if word not in ru_stopwords:
        #print(word)

# %%
rus_sample = '@zabanen_snova Ну. Трещит у неё, но она же в принципе тупая. У неё в глазах тупизна, ну пускай се кукарекает чо. Хотя эти прямые линии на самом деле в цирк с конями превратились. С другой стороны можно просто продолжать выполнять хорошо своё дело.'

# %%
type(rus_sample)

# %%
text

# %% [markdown]
# # Working code

# %%
#text3 = cleanup(twitter_contents[4])
import time
start = time.time()

cleantext, tokens = twitterdf.Contents.apply(cleanup)
print(output_list)
twitterdf['Cleaned_Text'] = cleantext
twitterdf['Tokenized_Text'] = tokens
end = time.time()
print(end-start)
#print(text3, '\n\n\n', twitter_contents[4])

# %%
text = re.sub(rustopwords, '', rus_sample)
tokens = [token for token in rus_sample.split() if token not in rustopwords\
            and token != " "]
    
text = " ".join(tokens)

# %%
# Iterates through tokenized text and removes the stopwords.

tokenized_text = nltk.word_tokenize(text)

for word in tokenized_text:
    if word not in ru_stopwords:
        print(word)

# %%
#twitter_contents
tokens = []

#for word in tokens:
    #if word not in ru_stopwords:
     #   print(word)
        
#print(type(tokens))

for x in twitter_contents[0:10]:
    #print(x)
    tokens.append(nltk.word_tokenize(x))
#print(tokens[0])

#tokens = nltk.word_tokenize(twitter_contents)
#tokens_text = nltk.Text(tokens)
tokens_text.concordance('Всемирный')

# %%
twitterdf[twitterdf.Contents.str.contains('Всемирный')]

# %%
twitterdf[twitterdf['Contents'].str.contains('http')]
#str.contains('og', regex=False)
# Out:
#                         Host  \
# 0     http://www.twitter.com
# 10    http://www.twitter.com
# 13    http://www.twitter.com
# 22    http://www.twitter.com
# 28    http://www.twitter.com
# 33    http://www.twitter.com
# 45    http://www.twitter.com
# 46    http://www.twitter.com
# 58    http://www.twitter.com
# 60    http://www.twitter.com
# 61    http://www.twitter.com
# 64    http://www.twitter.com
# 65    http://www.twitter.com
# 66    http://www.twitter.com
# 72    http://www.twitter.com
# 98    http://www.twitter.com
# 99    http://www.twitter.com
# 100   http://www.twitter.com
# 101   http://www.twitter.com
# 107   http://www.twitter.com
# 108   http://www.twitter.com
# 110   http://www.twitter.com
# 119   http://www.twitter.com
# 120   http://www.twitter.com
# 124   http://www.twitter.com
# 127   http://www.twitter.com
# 129   http://www.twitter.com
# 130   http://www.twitter.com
# 132   http://www.twitter.com
# 133   http://www.twitter.com
# ...                      ...
# 9502  http://www.twitter.com
# 9528  http://www.twitter.com
# 9558  http://www.twitter.com
# 9559  http://www.twitter.com
# 9560  http://www.twitter.com
# 9570  http://www.twitter.com
# 9584  http://www.twitter.com
# 9585  http://www.twitter.com
# 9587  http://www.twitter.com
# 9591  http://www.twitter.com
# 9602  http://www.twitter.com
# 9604  http://www.twitter.com
# 9606  http://www.twitter.com
# 9610  http://www.twitter.com
# 9611  http://www.twitter.com
# 9612  http://www.twitter.com
# 9613  http://www.twitter.com
# 9616  http://www.twitter.com
# 9619  http://www.twitter.com
# 9622  http://www.twitter.com
# 9623  http://www.twitter.com
# 9624  http://www.twitter.com
# 9629  http://www.twitter.com
# 9632  http://www.twitter.com
# 9646  http://www.twitter.com
# 9647  http://www.twitter.com
# 9648  http://www.twitter.com
# 9649  http://www.twitter.com
# 9650  http://www.twitter.com
# 9652  http://www.twitter.com
#
#                                                    Link             Date(ET)  \
# 9587             Melitopol0619   http://twitter.com/news_melitopol          5
# 9591            Васіль-Васілёк   http://twitter.com/_rapmons_wife_          5
# 9602                  KamboJia         http://twitter.com/kambojia          5
# 9604      Чемпионат Киберспорт      http://twitter.com/champ_cyber          6
# 9606            Афиша Кемерово      http://twitter.com/vse42afisha          5
# 9610           Ольга Вершинина       http://twitter.com/olenushka8          4
# 9611                E1.RU News           http://twitter.com/e1news          8
# 9612            Kirovchanka.ru    http://twitter.com/kirovchankaru          4
# 9613            Kirovchanka.ru    http://twitter.com/kirovchankaru          4
# 9616      ПетербургскийДневник       http://twitter.com/dnevnikspb          7
# 9619                  Kristina    http://twitter.com/_lion_heart17          0
# 9622           Судьба xoxлА™🇷🇺       http://twitter.com/sydbaxoxla          2
# 9623           Цирковой Артист    http://twitter.com/circusartist1          1
# 9624          Александр  Левин      http://twitter.com/buttonbagel          2
# 9629                 чашечка ☕      http://twitter.com/timelorddwl          8
# 9632          Hofbrau Kemerowo  http://twitter.com/hofbraukemerowo          1
# 9646      теплород и флогистон          http://twitter.com/klyasht          4
# 9647           Петров Владимир       http://twitter.com/vpetrov410          5
# 9648                    srsly?           http://twitter.com/e_booo          2
# 9649         Культурный регион         http://twitter.com/kult_bel          4
# 9650                      Глеб      http://twitter.com/g_likhachev          1
# 9652            Васіль-Васілёк   http://twitter.com/_rapmons_wife_          5
#
#       Followers  Following  Age  Gender Language  Country Province/State  \
# 0           441       2764  NaN     NaN  Russian      NaN            NaN
# 10            8         14  NaN    MALE  Russian  Ukraine            NaN
# 13            7         10  NaN     NaN  Russian      NaN            NaN
# 22         1092       1648  NaN     NaN  Russian      NaN            NaN
# 28           48        171  NaN     NaN  Russian      NaN            NaN
# 33           55        268  NaN    MALE  Russian      NaN            NaN
# 45            0          1  NaN     NaN  Russian      NaN            NaN
# 46            0          1  NaN     NaN  Russian      NaN            NaN
# 58          763       1198  NaN  FEMALE  Russian      NaN            NaN
# 60         5240        104  NaN     NaN  Russian      NaN            NaN
# 61          605        200  NaN     NaN  Russian      NaN            NaN
# 64           77        159  NaN     NaN  Russian      NaN            NaN
# 65         2903       1009  NaN     NaN  Russian      NaN            NaN
# 66           36         33  NaN     NaN  Russian      NaN            NaN
# 72           94        368  NaN    MALE  Russian      USA             dc
# 98            1         34  NaN     NaN  Russian      NaN            NaN
# 99         7901        363  NaN    MALE  Russian      NaN            NaN
# 100         461         33  NaN     NaN  Russian      NaN            NaN
# 101         292          1  NaN     NaN  Russian      NaN            NaN
# 107        1199       3103  NaN  FEMALE  Russian      USA             ny
# 108        1723        271  NaN     NaN  Russian      NaN            NaN
# 110           2         33  NaN     NaN  Russian  Ukraine            NaN
# 119         365          1  NaN     NaN  Russian      NaN            NaN
# 120        1100         42  NaN     NaN  Russian      NaN            NaN
# 124        1529       2331  NaN     NaN  Russian      NaN            NaN
# 127        1100         42  NaN     NaN  Russian      NaN            NaN
# 129         767        550  NaN     NaN  Russian      NaN            NaN
# 130         100         57  NaN     NaN  Russian      NaN            NaN
# 132          21        139  NaN     NaN  Russian      NaN            NaN
# 133        7407        306  NaN    MALE  Russian      NaN            NaN
# ...         ...        ...  ...     ...      ...      ...            ...
# 9502         79        135  NaN    MALE  Russian      NaN            NaN
# 9528        537        702  NaN     NaN  Russian      NaN            NaN
# 9558       2601       4639  NaN  FEMALE  Russian      NaN            NaN
# 9559       1828        187  NaN     NaN  Russian   Russia    moscow city
# 9560       2601       4639  NaN  FEMALE  Russian      NaN            NaN
# 9570        128        374  NaN  FEMALE  Russian      NaN            NaN
# 9584         73        149  NaN    MALE  Russian      NaN            NaN
# 9585        256        301  NaN  FEMALE  Russian   Russia    moscow city
# 9587        441          1  NaN     NaN  Russian      NaN            NaN
# 9591        660        481  NaN     NaN  Russian      NaN            NaN
# 9602        226        127  NaN     NaN  Russian      NaN            NaN
# 9604       1097          4  NaN     NaN  Russian      NaN            NaN
# 9606        559        217  NaN     NaN  Russian      NaN            NaN
# 9610        378        570  NaN     NaN  Russian      NaN            NaN
# 9611       9915         68  NaN     NaN  Russian      NaN            NaN
# 9612         76         22  NaN     NaN  Russian      NaN            NaN
# 9613         76         22  NaN     NaN  Russian      NaN            NaN
# 9616       3401         50  NaN     NaN  Russian      NaN            NaN
# 9619          0          1  NaN  FEMALE  Russian   Russia    chelyabinsk
# 9622         14          0  NaN     NaN  Russian      NaN            NaN
# 9623          4         53  NaN     NaN  Russian      NaN            NaN
# 9624         31        300  NaN     NaN  Russian      NaN            NaN
# 9629       7300       3922  NaN  FEMALE  Russian      NaN            NaN
# 9632          6         22  NaN     NaN  Russian      NaN            NaN
# 9646        111        125  NaN     NaN  Russian      NaN            NaN
# 9647        939       3458  NaN     NaN  Russian      NaN            NaN
# 9648         28        248  NaN     NaN  Russian      NaN            NaN
# 9649        202        118  NaN     NaN  Russian   Russia            NaN
# 9650         17         53  NaN     NaN  Russian      NaN            NaN
# 9652        660        481  NaN     NaN  Russian      NaN            NaN
#
#              City                        Location Sentiment       Themes  \
# 0             NaN  Якутск, Саха Якутия республика   NEUTRAL          NaN
# 10            NaN                         Ukraine   NEUTRAL          NaN
# 13            NaN                      Красноярск   NEUTRAL          NaN
# 22            NaN                             NaN   NEUTRAL          NaN
# 28            NaN                  Самара, Россия   NEUTRAL          NaN
# 33            NaN                 Нижний Новгород   NEUTRAL  technology;
# 45            NaN                  Липецк, Россия   NEUTRAL          NaN
# 46            NaN                  Липецк, Россия   NEUTRAL          NaN
# 58            NaN     Ставропольский край, Россия   NEUTRAL          NaN
# 60            NaN                 Минск, Беларусь   NEUTRAL          NaN
# 61            NaN                             NaN  POSITIVE          NaN
# 64            NaN                  Москва, Россия      NONE          NaN
# 65            NaN         г. Донецк - столица ДНР   NEUTRAL          NaN
# 66            NaN               Волгодонск-Москва   NEUTRAL  technology;
# 72     washington                  Washington, DC   NEUTRAL  technology;
# 98            NaN                             NaN   NEUTRAL  technology;
# 99            NaN                             NaN   NEUTRAL  technology;
# 100           NaN                 Санкт-Петербург   NEUTRAL  technology;
# 101           NaN                   Пермь, Россия   NEUTRAL          NaN
# 107      new york                        NYC, USA   NEUTRAL  technology;
# 108           NaN              Российская империя   NEUTRAL  technology;
# 110           NaN                         Ukraine   NEUTRAL  technology;
# 119           NaN                             NaN   NEUTRAL          NaN
# 120           NaN                 Россия, г. Тула   NEUTRAL          NaN
# 124           NaN                        USSR 2.0   NEUTRAL  technology;
# 127           NaN                 Россия, г. Тула   NEUTRAL          NaN
# 129           NaN           Донецк, город - герой   NEUTRAL  technology;
# 130           NaN         Санкт-Петербург, Россия   NEUTRAL  technology;
# 132           NaN                          Prspdn   NEUTRAL  technology;
# 133           NaN                             NaN   NEUTRAL  technology;
# ...           ...                             ...       ...          ...
# 9502          NaN                  Москва, Россия      NONE          NaN
# 9528          NaN                          Россия      NONE          NaN
# 9558          NaN                             NaN      NONE          NaN
# 9559       moscow                       Guangdong      NONE          NaN
# 9560          NaN                             NaN      NONE          NaN
# 9570          NaN               Вальхалла, Асгард      NONE          NaN
# 9584          NaN      Краснодарский край, Россия      NONE          NaN
# 9585       moscow                  Russia, Moscow      NONE          NaN
# 9587          NaN                         Украина      NONE          NaN
# 9591          NaN                 Мая хата з краю      NONE          NaN
# 9602          NaN                            Омск      NONE          NaN
# 9604          NaN                  Москва, Россия      NONE          NaN
# 9606          NaN                        Кемерово      NONE          NaN
# 9610          NaN         Санкт-Петербург, Россия      NONE          NaN
# 9611          NaN            Екатеринбург, Россия      NONE          NaN
# 9612          NaN                           Киров      NONE          NaN
# 9613          NaN                           Киров      NONE          NaN
# 9616          NaN                 Санкт-Петербург      NONE          NaN
# 9619  chelyabinsk               Челябинск, Россия      NONE          NaN
# 9622          NaN                             NaN      NONE          NaN
# 9623          NaN                  Москва, Россия      NONE          NaN
# 9624          NaN                          Москва      NONE          NaN
# 9629          NaN                     manga world      NONE          NaN
# 9632          NaN                Кемерово, Россия      NONE          NaN
# 9646          NaN                             NaN      NONE          NaN
# 9647          NaN                          Россия      NONE          NaN
# 9648          NaN                             NaN      NONE          NaN
# 9649          NaN                             NaN      NONE          NaN
# 9650          NaN                  Москва, Россия      NONE          NaN
# 9652          NaN                 Мая хата з краю      NONE          NaN
#
#                            Classifications Entities  Alexa Rank  Alexa Reach  \
# 0                         Product.grocery;   5 год;         NaN          NaN
# 10                                     NaN      NaN         NaN          NaN
# 13                                     NaN      NaN         NaN          NaN
# 22                                     NaN      NaN         NaN          NaN
# 28                                     NaN      NaN         NaN          NaN
# 33    Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 45                                     NaN      NaN         NaN          NaN
# 46                                     NaN      NaN         NaN          NaN
# 58                                     NaN      NaN         NaN          NaN
# 60                                     NaN      NaN         NaN          NaN
# 61                                     NaN      NaN         NaN          NaN
# 64                                     NaN      NaN         NaN          NaN
# 65                                     NaN      NaN         NaN          NaN
# 66                    Technology.software;      Qt;         NaN          NaN
# 72    Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 98    Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 99    Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 100                   Technology.software;      Qt;         NaN          NaN
# 101                                    NaN      NaN         NaN          NaN
# 107   Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 108   Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 110                   Technology.software;      Qt;         NaN          NaN
# 119                       Org.broadcaster;      RT;         NaN          NaN
# 120                                    NaN      NaN         NaN          NaN
# 124   Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 127                                    NaN      NaN         NaN          NaN
# 129   Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 130   Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 132   Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# 133   Technology.software;Org.broadcaster;   Qt;RT;         NaN          NaN
# ...                                    ...      ...         ...          ...
# 9502                                   NaN      NaN         NaN          NaN
# 9528                                   NaN      NaN         NaN          NaN
# 9558                                   NaN      NaN         NaN          NaN
# 9559                                   NaN      NaN         NaN          NaN
# 9560                                   NaN      NaN         NaN          NaN
# 9570                                   NaN      NaN         NaN          NaN
# 9584                                   NaN      NaN         NaN          NaN
# 9585                                   NaN      NaN         NaN          NaN
# 9587                                   NaN      NaN         NaN          NaN
# 9591                                   NaN      NaN         NaN          NaN
# 9602                                   NaN      NaN         NaN          NaN
# 9604                                   NaN      NaN         NaN          NaN
# 9606                                   NaN      NaN         NaN          NaN
# 9610                                   NaN      NaN         NaN          NaN
# 9611                                   NaN      NaN         NaN          NaN
# 9612                                   NaN      NaN         NaN          NaN
# 9613                                   NaN      NaN         NaN          NaN
# 9616                                   NaN      NaN         NaN          NaN
# 9619                                   NaN      NaN         NaN          NaN
# 9622                                   NaN      NaN         NaN          NaN
# 9623                                   NaN      NaN         NaN          NaN
# 9624                                   NaN      NaN         NaN          NaN
# 9629                                   NaN      NaN         NaN          NaN
# 9632                                   NaN      NaN         NaN          NaN
# 9646                                   NaN      NaN         NaN          NaN
# 9647                                   NaN      NaN         NaN          NaN
# 9648                                   NaN      NaN         NaN          NaN
# 9649                                   NaN      NaN         NaN          NaN
# 9650                                   NaN      NaN         NaN          NaN
# 9652                                   NaN      NaN         NaN          NaN
#
#       Title                                            Snippet  \
# 0       NaN  Всемирный известный Итальянский цирк приглашае...
# 10      NaN  Киев за 2 дня. День 2. #Киев #КрасивыеЗдания #...
# 13      NaN  Решили с подругой детей в цирк сводить. Ее дев...
# 22      NaN  Днем рождения Тверского цирка принято считать ...
# 28      NaN  @YDsNyHGmgeQ7Po8 устроили для детей праздник "...
# 33      NaN  QT @doofyrocks: RT @noizeof: Кандидат-ка на до...
# 45      NaN  ЦИРК! ЦИРК! ЦИРК! ⠀ Вчерашний день мы провели ...
# 46      NaN  ЦИРК! ЦИРК! ЦИРК! / / Вчерашний день мы провел...
# 58      NaN  Анонс!!!! / Пластилиновые картины с маленькими...
# 60      NaN  Музыка, танцы, игры, театр и цирк – День Польш...
# 61      NaN  2-е лето подряд получается осуществить мечту: ...
# 64      NaN  QT @HotlineDNR: !!! ; Общественники ДНР органи...
# 65      NaN  Общественники ДНР организовали поездку в донец...
# 66      NaN  QT @prof_preobr: 😂ору. Наши на рыбалку, а эти ...
# 72      NaN  QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 98      NaN  QT @juristnaprovode: RT @SPb_Petrovich: Это уж...
# 99      NaN  QT @juristnaprovode: RT @SPb_Petrovich: Это уж...
# 100     NaN  QT @juristnaprovode: Это уже сука, цирк с коня...
# 101     NaN  готов 6 выпуск новостей. В День рождения "Ново...
# 107     NaN  QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 108     NaN  QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 110     NaN  QT @BilanOfficial: сколько этот цирк еще продл...
# 119     NaN  RT @TulskieParki: Интересно и весело отпраздно...
# 120     NaN  Интересно и весело отпраздновали туляки День Р...
# 124     NaN  QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 127     NaN  ДеньРоссии #праздник #цирк https://t.co/Rum1TW...
# 129     NaN  QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 130     NaN  QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 132     NaN  QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 133     NaN  QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# ...     ...                                                ...
# 9502    NaN  QT @M_Simonyan: Взгляните на этот цирк. Поболь...
# 9528    NaN  QT @sharijnet: Цирк не интересен, когда выступ...
# 9558    NaN  QT @spacelordrock: самое забавное- это цирк у ...
# 9559    NaN  QT @dolg132005: Цирк который даже не репетиров...
# 9560    NaN  QT @segodnya_life: чокнутые укры- совесть есть...
# 9570    NaN  QT @spacelordrock: А из нормальных людей никто...
# 9584    NaN  QT @lolgamestream: Цирк не уехал и клоуны оста...
# 9585    NaN  QT @meduzaproject: Ха, а сколько за день предп...
# 9587    NaN  Областная власть сделала подарок мелитопольски...
# 9591    NaN  Спокойной ночи, любимые 💟 Как день прошел? Уст...
# 9602    NaN  QT @coffeeandvrooom: бедный Лэнсик https://t.c...
# 9604    NaN  Евгений Yozhyk Мостовик: на сегодняшний день с...
# 9606    NaN  Детский праздник "Все любят цирк"! ⠀ (0+) http...
# 9610    NaN  День Санкт-Петербурга! 🎉 / На Невском - цирк и...
# 9611    NaN  На этой неделе после работы предлагаем вам заг...
# 9612    NaN  RT @Kirovchankaru: Хотите выиграть билеты в ци...
# 9613    NaN  Хотите выиграть билеты в цирк на День города? ...
# 9616    NaN  🐘 В День города цирк Чинизелли устроил карнава...
# 9619    NaN  В этот прекрасный день я со своими близкими ез...
# 9622    NaN  @SemenGorbunkob А-ха-ха! Ну, рогуль, ну ты мен...
# 9623    NaN  ХI детские #pepsico игры через считанные минут...
# 9624    NaN  ХI детские #pepsico игры через считанные минут...
# 9629    NaN  последний друг стала люба..мда... вот от нее я...
# 9632    NaN  1 июня в 17:00 ресторан Hofbrau Kemerovo пригл...
# 9646    NaN  QT @Battlefield: Но вот посмотришь трейлер и в...
# 9647    NaN  QT @ZlayAlka: ....вместо того чтобы радоваться...
# 9648    NaN  QT @Newlifeua: Ебаный цирк, как с собчаками и ...
# 9649    NaN  💃🔥 Скоро больших и маленьких белгородцев ожида...
# 9650    NaN  Как-то ради смеха отправил заявку на участие в...
# 9652    NaN  Спокойной ночи,котики💟 Все хочу начать ложитьс...
#
#                                                Contents  \
# 0     Всемирный известный Итальянский цирк приглашае...
# 10    Киев за 2 дня. День 2. #Киев #КрасивыеЗдания #...
# 13    Решили с подругой детей в цирк сводить. Ее дев...
# 22    Днем рождения Тверского цирка принято считать ...
# 28    @YDsNyHGmgeQ7Po8 устроили для детей праздник "...
# 33    QT @doofyrocks: RT @noizeof: Кандидат-ка на до...
# 45    ЦИРК! ЦИРК! ЦИРК! ⠀ Вчерашний день мы провели ...
# 46    ЦИРК! ЦИРК! ЦИРК! / / Вчерашний день мы провел...
# 58    Анонс!!!! / Пластилиновые картины с маленькими...
# 60    Музыка, танцы, игры, театр и цирк – День Польш...
# 61    2-е лето подряд получается осуществить мечту: ...
# 64    QT @HotlineDNR: !!! ; Общественники ДНР органи...
# 65    Общественники ДНР организовали поездку в донец...
# 66    QT @prof_preobr: 😂ору. Наши на рыбалку, а эти ...
# 72    QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
#
T @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 98    QT @juristnaprovode: RT @SPb_Petrovich: Это уж...
# 99    QT @juristnaprovode: RT @SPb_Petrovich: Это уж...
# 100   QT @juristnaprovode: Это уже сука, цирк с коня...
# 101   готов 6 выпуск новостей. . В День рождения "Но...
# 107   QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 108   QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 110   #ДимаБилан - #ПроБелыеРозы! . Уже на всех цифр...
# 119   RT @TulskieParki: Интересно и весело отпраздно...
# 120   Интересно и весело отпраздновали туляки День Р...
# 124   QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 127                                                 NaN
# 129   QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 130   QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 132   QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# 133   QT @SobolLubov: RT @tov_sobakin: Цирк этот под...
# ...                                                 ...
# 9502  QT @M_Simonyan: Взгляните на этот цирк. . Побо...
# 9528                                                NaN
# 9558  QT @spacelordrock: самое забавное- это цирк у ...
# 9559  QT @dolg132005: Цирк который даже не репетиров...
# 9560  QT @segodnya_life: чокнутые укры- совесть есть...
# 9570  QT @spacelordrock: А из нормальных людей никто...
# 9584  QT @lolgamestream: Цирк не уехал и клоуны оста...
# 9585  QT @meduzaproject: Ха, а сколько за день предп...
# 9587  Областная власть сделала подарок мелитопольски...
# 9591  Спокойной ночи, любимые 💟 Как день прошел? . Н...
# 9602                                                NaN
# 9604  Евгений Yozhyk Мостовик: на сегодняшний день с...
# 9606  Детский праздник "Все любят цирк"! . ⠀ (0+) ht...
# 9610  День Санкт-Петербурга! . 🎉 / На Невском - цирк...
# 9611                                                NaN
# 9612  RT @Kirovchankaru: Хотите выиграть билеты в ци...
# 9613  Хотите выиграть билеты в цирк на День города? ...
# 9616  🐘 В День города цирк Чинизелли устроил карнава...
# 9619  В этот прекрасный день я со своими близкими ез...
# 9622  @SemenGorbunkob А-ха-ха! . Ну, рогуль, ну ты м...
# 9623                                                NaN
# 9624                                                NaN
# 9629  последний друг стала люба..мда... вот от нее я...
# 9632  1 июня в 17:00 ресторан Hofbrau Kemerovo пригл...
# 9646  QT @Battlefield: Но вот посмотришь трейлер и в...
# 9647  QT @ZlayAlka: ....вместо того чтобы радоваться...
# 9648  QT @Newlifeua: Ебаный цирк, как с собчаками и ...
# 9649  💃🔥 Скоро больших и маленьких белгородцев ожида...
# 9650  Как-то ради смеха отправил заявку на участие в...
# 9652  Спокойной ночи,котики💟 Все хочу начать ложитьс...
#
#                                                     Bio     Unique ID  \
# 0                        Государственный цирк - 25 лет!  1.141900e+18
# 10    Я студент, который учиться на программиста и у...  1.141390e+18
# 13    Имею возможность иметь козу, но не имею желани...  1.141300e+18
# 22    Новости о туризме и горящих турах, отзывы, сов...  1.140890e+18
# 28    Мама особенного ребёнка;  Учредитель НКО Возмо...  1.140690e+18
# 33                                                  NaN  1.140640e+18
# 45    Совмещаю декрет и работу в интернете, мама дво...  1.140540e+18
# 46    Совмещаю декрет и работу в интернете, мама дво...  1.140530e+18
# 58    🎨I am a painter.I like to drawing a wonderful ...  1.140110e+18
# 60    Официальный аккаунт издательского дома «Белару...  1.139990e+18
# 61    В #ЖКХ с 2006 г.                              ...  1.139980e+18
# 64                 ДУМАТЬ НЕ ВРЕДНО, ВРЕДНО НЕ ДУМАТЬ !  1.139870e+18
# 65    Донбасс никто не ставил на колени и никому пос...  1.139870e+18
# 66    http://www.stihi.ru/avtor/tatien12 Журналист, ...  1.139830e+18
# 72    живу в штатах. люблю Россию. патамушта Родина ...  1.139590e+18
# 98                                                  NaN  1.139180e+18
# 99                              При наличии отсутствия.  1.139180e+18
# 100                                                 NaN  1.139180e+18
# 101   Инстаграм - https://www.instagram.com/npcamp/ ...  1.139170e+18
# 107                                                 NaN  1.139080e+18
# 108   главред газеты Пихдёжъ, русский по рождению, и...  1.139070e+18
# 110                                                 NaN  1.139040e+18
# 119   Ретвиты о Туле. Я бот, не стоит мне писать, пр...  1.138880e+18
# 120               Городской центр отдыха и развлечений!  1.138880e+18
# 124                             They must be destroyed.  1.138820e+18
# 127               Городской центр отдыха и развлечений!  1.138780e+18
# 129                                                 NaN  1.138770e+18
# 130   Отсидел девять месяцев за ДЕСЯТЬ ЗАПОВЕДЕЙ РУС...  1.138760e+18
# 132                                                 NaN  1.138750e+18
# 133                                                 NaN  1.138750e+18
# ...                                                 ...           ...
# 9502                Любовь к Родине начинается с малого  1.002070e+18
# 9528  Давай, дружище, без обиды, Без журналисткой су...  1.002020e+18
# 9558                                                NaN  1.001960e+18
# 9559  Россия - Китай. Пишу не только про Китай, а во...  1.001950e+18
# 9560                                                NaN  1.001950e+18
# 9570  Хотите напасть на Россию? Нападайте прямо сейч...  1.001860e+18
# 9584                                   Рождённый в СССР  1.001840e+18
# 9585  Аня, люблю котиков, книги, фильмы, сериалки, н...  1.001830e+18
# 9587  Твиттер сайта города Мариуполя - http://0619.c...  1.001830e+18
# 9591                        •Няма таго, што раньш было•  1.001580e+18
# 9602  склонна к насилию, характер скверный. А свое м...  1.001150e+18
# 9604             https://www.championat.com/cybersport/  1.001120e+18
# 9606  Кино, концерты, события и еще много чего вкусн...  1.001030e+18
# 9610  Диагностика по языку, здоровье; путешествия, с...  1.001020e+18
# 9611                                      Новости E1.RU  1.000970e+18
# 9612  Кировский интернет-портал для женщин и всей семьи  1.000970e+18
# 9613  Кировский интернет-портал для женщин и всей семьи  1.000970e+18
# 9616  Ежедневное издание правительства Санкт-Петербурга  1.000780e+18
# 9619                                                NaN  1.000700e+18
# 9622                                                NaN  1.000480e+18
# 9623  Творческое объединение «Цирковой артист»!Мы сд...  1.000320e+18
# 9624          актёр, спортсмен, организатор мероприятий  1.000280e+18
# 9629                                       #loveyouself  1.000100e+18
# 9632  Первый в России баварский пивной ресторан Hofb...  9.999220e+17
# 9646                                      phls/lgc/yndx  9.993890e+17
# 9647  Если ты не являешься частью решения, значит ты...  9.993690e+17
# 9648                                                NaN  9.993320e+17
# 9649  Мы расскажем об интересных событиях в Белгород...  9.992660e+17
# 9650                                      Люблю мем кек  9.992530e+17
# 9652                        •Няма таго, што раньш было•  9.990480e+17
#
#                 Post Source
# 0        Twitter for iPhone
# 10                Instagram
# 13       VK.COM AUTH GROUPS
# 22                 Facebook
# 28      Twitter for Android
# 33       Twitter for iPhone
# 45                Instagram
# 46       VK.COM AUTH GROUPS
# 58       VK.COM AUTH GROUPS
# 60      NovaPress Publisher
# 61      Twitter for Android
# 64       Twitter Web Client
# 65    DnrHotline Autoposter
# 66      Twitter for Android
# 72       Twitter for iPhone
# 98       Twitter Web Client
# 99       Twitter Web Client
# 100      Twitter for iPhone
# 101         Twitter Web App
# 107        Twitter for iPad
# 108      Twitter Web Client
# 110      Twitter Web Client
# 119           RetweetFilter
# 120      Twitter Web Client
# 124     Twitter for Android
# 127      Twitter Web Client
# 129     Twitter for Android
# 130      Twitter for iPhone
# 132     Twitter for Android
# 133      Twitter Web Client
# ...                     ...
# 9502     Twitter for iPhone
# 9528    Twitter for Android
# 9558     Twitter Web Client
# 9559     Twitter for iPhone
# 9560     Twitter Web Client
# 9570           Twitter Lite
# 9584     Twitter Web Client
# 9585    Twitter for Android
# 9587    NovaPress Publisher
# 9591    Twitter for Android
# 9602     Twitter Web Client
# 9604                Amplifr
# 9606     Twitter Web Client
# 9610                 vk.com
# 9611     Twitter Web Client
# 9612     Twitter Web Client
# 9613     Twitter Web Client
# 9616              TweetDeck
# 9619     Twitter for iPhone
# 9622           Twitter Lite
# 9623     Twitter for iPhone
# 9624     Twitter for iPhone
# 9629    Twitter for Android
# 9632           vk.com pages
# 9646     Twitter Web Client
# 9647     Twitter for iPhone
# 9648    Twitter for Android
# 9649     Twitter Web Client
# 9650       Twitter for iPad
# 9652    Twitter for Android
#
# [3520 rows x 32 columns]

# %%
twitterdf.Contents[0]
# Out:
# 'Всемирный известный Итальянский цирк приглашает с 20 июля по 18 августа на удивительную шоу-программу «СЛОНЫ и ТИГРЫ». Подарите праздник себе и вашим близким. ДЕТИ ДО 5 ЛЕТ БЕСПЛАТНО! Справки по телефону: +7(800) 700-02-71 Телефон кассы цирка:42-95-68; 735-537 https://t.co/uUBFgDCMZg'

# %% [markdown]
# # Functions

# %%
#Preprocess function

def cleanup(text):
    rustopwords = ' '.join(ru_stopwords[:])
    #cstart = time.time()
    # insert a space between hashtags
    text = re.sub("\#"," ", text)
    
    # remove urls 
    text = re.sub("(http|https)\:\/\/.*\s?","",text)
    
    # remove HTML tags
    text = re.sub("\<.*\>","",text)
    
    # remove punctuation
    text = text.translate(str.maketrans('', '', punctuation))
    #cend = time.time()
    #print(text)
    #print("cleanup time:",cend - cstart)
   
    #text = re.sub(rustopwords, '', text)
    
    
    
    tokens = [token for token in text.lower().split() if token not in rustopwords\
            and token != " "]
    
    text = " ".join(tokens)
    
# Add a new column as a function of existing columns.

    #drinks['servings'] = drinks.beer + drinks.spirit + drinks.wine

    #drinks['mL'] = drinks.liters * 1000
    
    #return text.strip()
    return text

# %%
#print(twitterdf['Contents'][0])
#print('')
print(cleanup(twitterdf))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-809-72ed94d4c807> in <module>
#       1 #print(twitterdf['Contents'][0])
#       2 #print('')
# ----> 3 print(cleanup(twitterdf))
#
# <ipython-input-763-6705305bb90f> in cleanup(text)
#       5     #cstart = time.time()
#       6     # insert a space between hashtags
# ----> 7     text = re.sub("\#"," ", text)
#       8
#       9     # remove urls
#
# ~\AppData\Local\Continuum\anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# Function returns the number of NaNs in the Title, Snippet, Contents and Summary columns of the forumsdf, newsdf, tumblrdf, twitterdf.
# The function requires four dataframes to work.

def NaN_count(data1, data2, data3, data4):
#def NaN_count(data1):

    name1 =[x for x in globals() if globals()[x] is data1][0]
    name2 =[x for x in globals() if globals()[x] is data2][0]
    name3 =[x for x in globals() if globals()[x] is data3][0]
    name4 =[x for x in globals() if globals()[x] is data4][0]
    
    print("NaN Results: %s" % name1)
    print('')
    print('There are', len(data1), 'total posts')
    print('Title:', data1['Title'].isna().sum())
    print('Snippet:', data1['Snippet'].isna().sum())
    print('Contents:', data1['Contents'].isna().sum())
    print('Summary:', data1['Summary'].isna().sum())
    print('')
    
    print("NaN Results: %s" % name2)
    print('')
    print('There are', len(data2), 'total posts')
    print('Title:', data2['Title'].isna().sum())
    print('Snippet:', data2['Snippet'].isna().sum())
    print('Contents:', data2['Contents'].isna().sum())
    print('Summary:', data2['Summary'].isna().sum())
    print('')
    
    print("NaN Results: %s" % name3)
    print('')
    print('There are', len(data3), 'total posts')
    print('Title:', data3['Title'].isna().sum())
    print('Snippet:', data3['Snippet'].isna().sum())
    print('Contents:', data3['Contents'].isna().sum())
    print('Summary:', data3['Summary'].isna().sum())
    print('')
    
    print("NaN Results: %s" % name4)
    print('')
    print('There are', len(data4), 'total posts')
    print('Title:', data4['Title'].isna().sum())
    print('Snippet:', data4['Snippet'].isna().sum())
    print('Contents:', data4['Contents'].isna().sum())
    print('Summary:', data4['Summary'].isna().sum())

# %%
NaN_count(forumsdf, newsdf, tumblrdf, twitterdf)
# Out:
# NaN Results: forumsdf
#
# There are 17600 total posts
# Title: 0
# Snippet: 1
# Contents: 1
# Summary: 412
#
# NaN Results: newsdf
#
# There are 9584 total posts
# Title: 1
# Snippet: 0
# Contents: 0
# Summary: 9
#
# NaN Results: tumblrdf
#
# There are 613 total posts
# Title: 41
# Snippet: 187
# Contents: 187
# Summary: 0
#
# NaN Results: twitterdf
#
# There are 9657 total posts
# Title: 9657
# Snippet: 0
# Contents: 0
# Summary: 1284

# %%
twitterdf.head()
# Out:
#                      Host                                               Link  \
# 0  http://www.twitter.com  http://twitter.com/diamondcircus/statuses/1141...
# 1  http://www.twitter.com  http://twitter.com/feronianya/statuses/1141728...
# 2  http://www.twitter.com  http://twitter.com/IPIi38622976/statuses/11417...
# 3  http://www.twitter.com  http://twitter.com/SaviorMars/statuses/1141703...
# 4  http://www.twitter.com  http://twitter.com/vkovall/statuses/1141701650...
#
#               Date(ET)             Time(ET)            LocalTime  Category  \
# 0  2019-06-20 00:00:00  2019-07-03 23:04:15  2019-06-20 23:04:00       NaN
# 1  2019-06-20 00:00:00  2019-07-03 11:25:14  2019-06-20 11:25:00       NaN
# 2  2019-06-20 00:00:00  2019-07-03 09:55:32  2019-06-20 09:55:00       NaN
# 3  2019-06-20 00:00:00  2019-07-03 09:43:38  2019-06-20 09:43:00       NaN
# 4  2019-06-20 00:00:00  2019-07-03 09:37:40  2019-06-20 09:37:00       NaN
#
#        Author ID         Author Name                        Author URL  \
# 0  diamondcircus  Бриллиантовый цирк  http://twitter.com/diamondcircus
# 1     feronianya             любимая     http://twitter.com/feronianya
# 2   IPIi38622976          🆘I PI🆘 .i.   http://twitter.com/ipii38622976
# 3     SaviorMars              Savior     http://twitter.com/saviormars
# 4        vkovall       Vasiliy Koval        http://twitter.com/vkovall
#
#    Authority  Followers  Following  Age Gender Language Country  \
# 0          4        441       2764  NaN    NaN  Russian     NaN
# 1          5        451        350  NaN   MALE  Russian     NaN
# 2          4        128        297  NaN    NaN  Russian     NaN
# 3          6       1152        186  NaN    NaN  Russian     NaN
# 4          6       1127        209  NaN   MALE  Russian  Russia
#
#   Province/State    City                        Location Sentiment Themes  \
# 0            NaN     NaN  Якутск, Саха Якутия республика   NEUTRAL    NaN
# 1            NaN     NaN                 г. Нижний Тагил   NEUTRAL    NaN
# 2            NaN     NaN                             NaN   NEUTRAL    NaN
# 3            NaN     NaN                  Москва, Россия   NEUTRAL    NaN
# 4  khanty-mansiy  surgut      msk, spb,  surgut, Russia.   NEUTRAL    NaN
#
#     Classifications Entities  Alexa Rank  Alexa Reach  Title  \
# 0  Product.grocery;   5 год;         NaN          NaN    NaN
# 1               NaN      NaN         NaN          NaN    NaN
# 2  Org.broadcaster;      RT;         NaN          NaN    NaN
# 3               NaN      NaN         NaN          NaN    NaN
# 4               NaN      NaN         NaN          NaN    NaN
#
#                                              Snippet  \
# 0  Всемирный известный Итальянский цирк приглашае...
# 1  Самое интересное , что она так и не поняла сут...
# 2  RT @vkovall: @zabanen_snova Ну. Трещит у неё, ...
# 3  как же это уже все заебало — сперва четырехчас...
# 4  @zabanen_snova Ну. Трещит у неё, но она же в п...
#
#                                             Contents  \
# 0  Всемирный известный Итальянский цирк приглашае...
# 1  Самое интересное , что она так и не поняла сут...
# 2  RT @vkovall: @zabanen_snova Ну. Трещит у неё, ...
# 3  как же это уже все заебало — сперва четырехчас...
# 4  @zabanen_snova Ну. Трещит у неё, но она же в п...
#
#                                              Summary  \
# 0  Всемирный известный Итальянский цирк приглашае...
# 1  Самое интересное , что она так и не поняла сут...
# 2  У неё в глазах тупизна, ну пускай се кукарекае...
# 3                                                NaN
# 4  У неё в глазах тупизна, ну пускай се кукарекае...
#
#                                                  Bio     Unique ID  \
# 0                     Государственный цирк - 25 лет!  1.141900e+18
# 1                                              д н о  1.141730e+18
# 2                                                NaN  1.141710e+18
# 3                                                NaN  1.141700e+18
# 4  Если тебе плохо - вспомни Ленинград 1941-1942 ...  1.141700e+18
#
#            Post Source
# 0   Twitter for iPhone
# 1   Twitter for iPhone
# 2  Twitter for Android
# 3   Twitter for iPhone
# 4   Twitter for iPhone

# %% [markdown]
# # Word Cloud

# %%
# ?WordCloud

# %%
# t = twitterdf['Contents'][0]
t = ''.join(post for post in twitterdf.Contents)
print('there are {} words in the combination of all review.'.format(len(t)))
# Out:
# there are 2166147 words in the combination of all review.

# %%
stopwords = set(rustopwords)

# %%
wordcloud = WordCloud(width=400, height=200, scale=1, stopwords=stopwords, background_color='white').generate(t)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
#plt.figure(figsize=[1,1])
plt.axis('off')
plt.show()

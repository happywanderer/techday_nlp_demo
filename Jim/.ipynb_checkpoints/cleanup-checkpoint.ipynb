# %%
import pandas as pd

# read in dfs
forumsdf = pd.read_csv('./data/clean_dfs/forums.csv')
newsdf = pd.read_csv('./data/clean_dfs/news.csv')
instagramdf = pd.read_csv('./data/clean_dfs/instagram.csv')
tumblrdf = pd.read_csv('./data/clean_dfs/tumblr.csv')
twitterdf = pd.read_csv('./data/clean_dfs/twitter.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-5ff664e56f69> in <module>
#       2
#       3 # read in dfs
# ----> 4 forumsdf = pd.read_csv('./data/clean_dfs/forums.csv')
#       5 newsdf = pd.read_csv('./data/clean_dfs/news.csv')
#       6 instagramdf = pd.read_csv('./data/clean_dfs/instagram.csv')
#
# ...

# %%
newsdf.shape
# Out:
# (9584, 32)

# %%
#import pandas as pd
import re
import time
from nltk.corpus import stopwords
from pymystem3 import Mystem
from string import punctuation

print(punctuation)
#Create lemmatizer and stopwords list
#mystem = Mystem() 
russian_stopwords = stopwords.words("russian")
#regex = re.compile('[%s]' % re.escape(string.punctuation))

#Preprocess function
def cleanup(text):
    #cstart = time.time()
    # insert a space between hashtags
    text = re.sub("\#"," ", text)
    
    # remove urls 
    text = re.sub("https\:\/\/.*\s","",text)
    
    # remove HTML tags
    text = re.sub("\<.*\>","",text)
    
    # remove punctuation
    text = text.translate(str.maketrans('', '', punctuation))
    #cend = time.time()
    #print(text)
    #print("cleanup time:",cend - cstart)
    
    
    #tokens = [token for token in tokens if token not in russian_stopwords\
    #          and token != " "]
    
    #text = " ".join(tokens)
    
    #return text.strip()
    return text
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
import time
#import numpy as np

#print(forumsdf[forumsdf["Contents"].isnull()])
#print(twitterdf[twitterdf["Contents"].isnull()])
#print(instagramdf[instagramdf["Contents"].isnull()])
print(tumblrdf[tumblrdf["Contents"].isnull()])
#newsdf["Contents"].replace()

#def lemmatize_text(text):
#    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

start = time.time()
#newsdf['Cleaned_Text'] = newsdf.Contents.apply(cleanup)
#instagramdf['Cleaned_Text'] = instagramdf.Contents.apply(cleanup)
#twitterdf['Cleaned_Text'] = twitterdf.Contents.apply(cleanup)
#print(cleanup(newsdf.Contents[1]))
end = time.time()

print(end - start)
# Out:
#           Host                            Link             Date(ET)  \
# 2    tumblr.co  https://tmblr.co/ZyZzNY2itPYkT  2019-06-15 00:00:00
# 3    tumblr.co  https://tmblr.co/Zfw6Ks2irYYVJ  2019-06-14 00:00:00
# 5    tumblr.co  https://tmblr.co/ZWYqnd2iq59Sg  2019-06-13 00:00:00
# 6    tumblr.co  https://tmblr.co/ZSpF0Y2iq5613  2019-06-13 00:00:00
# 7    tumblr.co  https://tmblr.co/ZG2D0Y2iq52lH  2019-06-13 00:00:00
# 8    tumblr.co  https://tmblr.co/Z-aD0Y2iq4_qx  2019-06-13 00:00:00
# 9    tumblr.co  https://tmblr.co/ZyXh-X2iq4z7u  2019-06-13 00:00:00
# 10   tumblr.co  https://tmblr.co/Zu8h-X2iq4yuQ  2019-06-13 00:00:00
# 11   tumblr.co  https://tmblr.co/ZtJh-X2iq4w7Y  2019-06-13 00:00:00
# 12   tumblr.co  https://tmblr.co/Z6YDwl2imBUSp  2019-06-10 00:00:00
# 28   tumblr.co  https://tmblr.co/Za782Y2iYl1tW  2019-05-31 00:00:00
# 30   tumblr.co  https://tmblr.co/ZxPheo2iUpInP  2019-05-28 00:00:00
# 31   tumblr.co  https://tmblr.co/ZgRBBf2iUgALd  2019-05-28 00:00:00
# ...

# %%
newsdf
# Out:
#                             Host  \
# 0       http://sakhalinmedia.ru/
# 1    http://mirtesen.sputnik.ru/
# 2  https://news.myseldon.com/ru/
# 3            http://www.trud.ru/
# 4      https://www.bragazeta.ru/
#
#                                                 Link             Date(ET)  \
# 0              https://sakhalinmedia.ru/news/824534/  2019-06-20 00:00:00
# 1  http://mirtesen.sputnik.ru/blog/43460930378/Af...  2019-06-20 00:00:00
# 2  https://news.myseldon.com/ru/news/index/212361...  2019-06-20 00:00:00
# 3  http://www.trud.ru/article/21-06-2019/1377277_...  2019-06-20 00:00:00
# 4            https://www.bragazeta.ru/world/2847395/  2019-06-20 00:00:00
#
#               Time(ET)            LocalTime  Category  Author ID  \
# 0  2019-07-03 23:15:17  2019-06-20 23:15:00       NaN        NaN
# 1  2019-07-03 23:11:37  2019-06-20 23:11:00       NaN        NaN
# 2  2019-07-03 20:13:27  2019-06-20 20:13:00       NaN        NaN
# ...
